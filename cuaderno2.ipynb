# %%
import pandas as pd

# %%
data = pd.read_csv("personas.csv")

# %%
data
# Out:
#                  nombre    apellido                           mail  \
# 0        Rebecca Farmer        Hall          currylisa@example.com
# 1       Bradley Johnson       Allen            ftorres@example.com
# 2         Bruce Solomon       Tyler    williamsmichael@example.com
# 3       Dustin Thompson  Richardson      holdenmelissa@example.org
# 4            Todd Mason     Barrett      torreskathryn@example.org
# 5      Mitchell Jackson      Howard           ibarnett@example.net
# 6         Jamie Bradley      Wright       shelbytaylor@example.net
# 7             Mary Rice        Hall            molly36@example.net
# 8          Joshua Young       Smith           tmeadows@example.com
# 9      Valerie Mitchell     Watkins      heatherrobles@example.com
# 10         Emily Walker       Stein            heidi22@example.com
# 11      Mr. Zachary Liu      Howard       susanswanson@example.org
# 12         Jamie Carter      Taylor              jdiaz@example.com
# ...

# %%
import pygwalker as pyg

# %%
pyg.walk(data)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000633f9b985c49cnfKgbXxcLV02RdyM" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000633f9b985c49cnfKgbXxcLV02RdyM") {
#             var iframe = document.getElementById("gwalker-000633f9b985c49cnfKgbXxcLV02RdyM");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
